# %% [markdown]
# ## if / elif / else

# %%
# task 1.
num = int(input('Enter a number: '))
if num > 0:
    print(num, 'is positive')

# %%
# task 2.
num = int(input('Enter a number: '))
if num < 0:
    print(num, 'is negative')

# %%
# task 3.
num = int(input('Enter a number: '))
if num == 0:
    print('The number is zero')

# %%
# task 4.
age = int(input('Enter age: '))
if age >= 18:
    print('Eligible to vote')

# %%
# task 5.
marks = int(input('Enter marks: '))
if marks >= 35:
    print('Student has passed')

# %%
# task 6.
num = int(input('Enter a number: '))
if num % 2 == 0:
    print(num, 'is even')

# %%
# task 7.
num = int(input('Enter a number: '))
if num % 2 != 0:
    print(num, 'is odd')

# %%
# task 8.
age = int(input('Enter age: '))
if age >= 60:
    print('Senior citizen')

# %%
# task 9.
num = int(input('Enter a number: '))
if num > 100:
    print(num, 'is greater than 100')

# %%
# task 10.
age = int(input('Enter age: '))
if age >= 18:
    print('Can apply for driving license')

# %%
# task 11.
num = int(input('Enter a number: '))
if num % 2 == 0:
    print(num, 'is even')
else:
    print(num, 'is odd')

# %%
# task 12.
num = int(input('Enter a number: '))
if num >= 0:
    print(num, 'is positive')
else:
    print(num, 'is negative')

# %%
# task 13.
age = int(input('Enter age: '))
if age >= 18:
    print('Eligible to vote')
else:
    print('Not eligible to vote')

# %%
# task 14.
marks = int(input('Enter marks: '))
if marks >= 35:
    print('Pass')
else:
    print('Fail')

# %%
# task 15.
num = int(input('Enter a number: '))
if num % 5 == 0:
    print(num, 'is divisible by 5')
else:
    print(num, 'is not divisible by 5')

# %%
# task 16.
a = int(input('Enter first number: '))
b = int(input('Enter second number: '))
if a > b:
    print(a, 'is greater')
else:
    print(b, 'is greater')

# %%
# task 17.
year = int(input('Enter a year: '))
if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
    print(year, 'is a leap year')
else:
    print(year, 'is not a leap year')

# %%
# task 18.
ch = input('Enter a character: ').lower()
if ch in 'aeiou':
    print(ch, 'is a vowel')
else:
    print(ch, 'is a consonant')

# %%
# task 19.
num = int(input('Enter a number: '))
if num % 2 == 0 and num % 3 == 0:
    print(num, 'is divisible by both 2 and 3')
else:
    print(num, 'is not divisible by both 2 and 3')

# %%
# task 20.
age = int(input('Enter age: '))
if age > 60:
    print('Eligible for discount')
else:
    print('Not eligible for discount')

# %%
# task 21.
num = int(input('Enter a number: '))
if num > 0:
    print('Positive')
elif num < 0:
    print('Negative')
else:
    print('Zero')

# %%
# task 22.
marks = int(input('Enter marks: '))
if marks >= 90:
    print('Grade: A')
elif marks >= 75:
    print('Grade: B')
elif marks >= 50:
    print('Grade: C')
elif marks >= 35:
    print('Grade: D')
else:
    print('Fail')

# %%
# task 23.
a = int(input('Enter first number: '))
b = int(input('Enter second number: '))
c = int(input('Enter third number: '))
if a >= b and a >= c:
    print(a, 'is the largest')
elif b >= a and b >= c:
    print(b, 'is the largest')
else:
    print(c, 'is the largest')

# %%
# task 24.
n1 = float(input('Enter first number: '))
op = input('Enter operator (+, -, *, /): ')
n2 = float(input('Enter second number: '))
if op == '+':
    print('Result:', n1 + n2)
elif op == '-':
    print('Result:', n1 - n2)
elif op == '*':
    print('Result:', n1 * n2)
elif op == '/':
    if n2 != 0:
        print('Result:', n1 / n2)
    else:
        print('Cannot divide by zero')
else:
    print('Invalid operator')

# %%
# task 25.
signal = input('Enter signal color (red/yellow/green): ').lower()
if signal == 'red':
    print('Stop')
elif signal == 'yellow':
    print('Get ready')
elif signal == 'green':
    print('Go')
else:
    print('Invalid signal')

# %% [markdown]
# ## Loops

# %%
# task 26.
for i in range(1, 6):
    print(i)

# %%
# task 27.
for i in range(5, 0, -1):
    print(i)

# %%
# task 28.
for i in range(3):
    print('Aryan Mehta')

# %%
# task 29.
for i in range(1, 11):
    print(i)

# %%
# task 30.
for i in range(2, 21, 2):
    print(i, end=' ')

# %%
# task 31.
for i in range(1, 21, 2):
    print(i, end=' ')

# %%
# task 32.
total = 0
for i in range(1, 11):
    total += i
print('Sum:', total)

# %%
# task 33.
n = int(input('Enter a number: '))
for i in range(1, 11):
    print(n, 'x', i, '=', n * i)

# %%
# task 34.
for i in range(1, 11):
    print(i, 'squared =', i ** 2)

# %%
# task 35.
for i in range(1, 11):
    print(i, 'cubed =', i ** 3)

# %%
# task 36.
n = int(input('Enter a number: '))
fact = 1
for i in range(1, n + 1):
    fact *= i
print('Factorial:', fact)

# %%
# task 37.
word = input('Enter a string: ')
count = 0
for ch in word:
    if ch.lower() in 'aeiou':
        count += 1
print('Vowels:', count)

# %%
# task 38.
word = input('Enter a string: ')
rev = ''
for ch in word:
    rev = ch + rev
print('Reversed:', rev)

# %%
# task 39.
word = input('Enter a string: ')
count = 0
for ch in word:
    count += 1
print('Total characters:', count)

# %%
# task 40.
rows = int(input('Enter number of rows: '))
for i in range(1, rows + 1):
    print('* ' * i)

# %%
# task 41.
i = 1
while i <= 5:
    print(i)
    i += 1

# %%
# task 42.
i = 5
while i >= 1:
    print(i)
    i -= 1

# %%
# task 43.
n = int(input('Enter a number: '))
count = 0
while n != 0:
    count += 1
    n //= 10
print('Digits:', count)

# %%
# task 44.
n = int(input('Enter a number: '))
rev = 0
while n != 0:
    rev = rev * 10 + n % 10
    n //= 10
print('Reversed:', rev)

# %%
# task 45.
n = int(input('Enter a number: '))
digit_sum = 0
temp = n
while temp != 0:
    digit_sum += temp % 10
    temp //= 10
print('Sum of digits:', digit_sum)

# %%
# task 46.
n = int(input('Enter a number: '))
orig = n
rev = 0
while n != 0:
    rev = rev * 10 + n % 10
    n //= 10
if orig == rev:
    print(orig, 'is a palindrome')
else:
    print(orig, 'is not a palindrome')

# %%
# task 47.
n = int(input('Enter a number: '))
fact = 1
i = 1
while i <= n:
    fact *= i
    i += 1
print('Factorial:', fact)

# %%
# task 48.
n = int(input('How many terms? '))
a, b = 0, 1
count = 0
while count < n:
    print(a, end=' ')
    a, b = b, a + b
    count += 1

# %%
# task 49.
i = 1
while i <= 10:
    print(i, 'squared =', i ** 2)
    i += 1

# %%
# task 50.
saved_user = 'aryan'
saved_pass = 'secure123'
attempts = 0
while attempts < 3:
    username = input('Username: ')
    password = input('Password: ')
    if username == saved_user and password == saved_pass:
        print('Login successful!')
        break
    else:
        attempts += 1
        print('Wrong credentials.', 3 - attempts, 'attempt(s) left')
else:
    print('Account locked.')

# %% [markdown]
# ## Functions

# %%
# task 1.
def greet():
    print('Hello, World!')
greet()

# %%
# task 2.
def display_name():
    print('Aryan Mehta')
display_name()

# %%
# task 3.
def print_numbers():
    for i in range(1, 11):
        print(i)
print_numbers()

# %%
# task 4.
def even_numbers():
    for i in range(2, 21, 2):
        print(i, end=' ')
even_numbers()

# %%
# task 5.
def odd_numbers():
    for i in range(1, 21, 2):
        print(i, end=' ')
odd_numbers()

# %%
# task 6.
def table_of_5():
    for i in range(1, 11):
        print(5, 'x', i, '=', 5 * i)
table_of_5()

# %%
# task 7.
def square(n):
    print('Square:', n ** 2)
square(int(input('Enter a number: ')))

# %%
# task 8.
def cube(n):
    print('Cube:', n ** 3)
cube(int(input('Enter a number: ')))

# %%
# task 9.
def add(a, b):
    print('Sum:', a + b)
add(int(input('Enter first number: ')), int(input('Enter second number: ')))

# %%
# task 10.
def subtract(a, b):
    print('Difference:', a - b)
subtract(int(input('Enter first number: ')), int(input('Enter second number: ')))

# %%
# task 11.
def multiply(a, b):
    print('Product:', a * b)
multiply(int(input('Enter first number: ')), int(input('Enter second number: ')))

# %%
# task 12.
def divide(a, b):
    if b != 0:
        print('Result:', a / b)
    else:
        print('Cannot divide by zero')
divide(float(input('Enter first number: ')), float(input('Enter second number: ')))

# %%
# task 13.
def maximum(a, b):
    if a > b:
        print(a, 'is maximum')
    else:
        print(b, 'is maximum')
maximum(int(input('Enter first number: ')), int(input('Enter second number: ')))

# %%
# task 14.
def minimum(a, b):
    if a < b:
        print(a, 'is minimum')
    else:
        print(b, 'is minimum')
minimum(int(input('Enter first number: ')), int(input('Enter second number: ')))

# %%
# task 15.
def even_or_odd(n):
    if n % 2 == 0:
        print(n, 'is even')
    else:
        print(n, 'is odd')
even_or_odd(int(input('Enter a number: ')))

# %%
# task 16.
def check_sign(n):
    if n > 0:
        print('Positive')
    elif n < 0:
        print('Negative')
    else:
        print('Zero')
check_sign(int(input('Enter a number: ')))

# %%
# task 17.
def factorial(n):
    fact = 1
    for i in range(1, n + 1):
        fact *= i
    print('Factorial:', fact)
factorial(int(input('Enter a number: ')))

# %%
# task 18.
def divisible_by_5(n):
    if n % 5 == 0:
        print(n, 'is divisible by 5')
    else:
        print(n, 'is not divisible by 5')
divisible_by_5(int(input('Enter a number: ')))

# %%
# task 19.
def count_chars(s):
    print('Character count:', len(s))
count_chars(input('Enter a string: '))

# %%
# task 20.
def largest(a, b, c):
    if a >= b and a >= c:
        print(a, 'is the largest')
    elif b >= a and b >= c:
        print(b, 'is the largest')
    else:
        print(c, 'is the largest')
largest(int(input('Enter first: ')), int(input('Enter second: ')), int(input('Enter third: ')))

# %%
# task 21.
def get_square(n):
    return n ** 2
print('Square:', get_square(int(input('Enter a number: '))))

# %%
# task 22.
def get_cube(n):
    return n ** 3
print('Cube:', get_cube(int(input('Enter a number: '))))

# %%
# task 23.
def get_sum(a, b):
    return a + b
print('Sum:', get_sum(int(input('Enter first: ')), int(input('Enter second: '))))

# %%
# task 24.
def get_product(a, b):
    return a * b
print('Product:', get_product(int(input('Enter first: ')), int(input('Enter second: '))))

# %%
# task 25.
def get_factorial(n):
    fact = 1
    for i in range(1, n + 1):
        fact *= i
    return fact
print('Factorial:', get_factorial(int(input('Enter a number: '))))

# %%
# task 26.
def reverse_string(s):
    return s[::-1]
print('Reversed:', reverse_string(input('Enter a string: ')))

# %%
# task 27.
def count_vowels(s):
    return sum(1 for ch in s.lower() if ch in 'aeiou')
print('Vowels:', count_vowels(input('Enter a string: ')))

# %%
# task 28.
def get_largest(lst):
    return max(lst)
nums = [34, 12, 78, 5, 90]
print('Largest:', get_largest(nums))

# %%
# task 29.
def get_smallest(lst):
    return min(lst)
nums = [34, 12, 78, 5, 90]
print('Smallest:', get_smallest(nums))

# %%
# task 30.
def get_average(a, b, c, d, e):
    return (a + b + c + d + e) / 5
print('Average:', get_average(
    float(input('Enter number 1: ')),
    float(input('Enter number 2: ')),
    float(input('Enter number 3: ')),
    float(input('Enter number 4: ')),
    float(input('Enter number 5: '))
))
